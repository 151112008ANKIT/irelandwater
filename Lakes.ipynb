# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
#impoorting and ploting River data
riv = gpd.read_file('Rivers&Lakes/Shapefiles/WATER_RivNetRoutes.shp')

# %%
riv.crs
# Out:
# <Derived Projected CRS: EPSG:29902>
# Name: TM65 / Irish Grid
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Ireland - onshore.
# - bounds: (-10.56, 51.39, -5.93, 55.43)
# Coordinate Operation:
# - name: Irish Grid
# - method: Transverse Mercator
# Datum: TM65
# - Ellipsoid: Airy Modified 1849
# - Prime Meridian: Greenwich

# %%
type(riv)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
len(riv)
# Out:
# 102108

# %%
riv
# Out:
#         OBJECTID       SEG_CD                   EPA_NAME EPA_CODE  ORDER_  \
# 0         350347         01_1                       None     None       1
# 1         350348        01_10                       None     None       1
# 2         350349       01_100                       None     None       1
# 3         350350     01_100_1                       None     None       1
# 4         350351      01_1000                  KINLETTER    01K01       1
# ...          ...          ...                        ...      ...     ...
# 102103    467131  GBNI0302979                       None     None       3
# 102104    467132  GBNI0302981                       None     None       1
# 102105    467133  GBNI0302989                       None     None       1
# 102106    467135  GBNI9901138  Cor Trib, Annareagh South    03C51       1
# 102107    467136     Temp19_1                       None     None       2
#
#        CONTINUA              RWB_CD LWB_CD TWB_CD   SegmentLen CWB_CD  \
# ...

# %%
riv.plot(cmap='jet',figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
riv.plot(cmap='jet',column='EPA_NAME',figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
#impoorting and ploting Lake data
lak= gpd.read_file('Rivers&Lakes/Shapefiles/WFD_LakeSegment.shp')

# %%
lak.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
lak
# Out:
#        OBJECTID   SEG_CD                NAME  AREA_     HECTARE    PERIMETER  \
# 0             1     34_1                None  0.002    0.174650   148.152773
# 1             2     34_2                None  0.002    0.168753   145.631645
# 2             3     34_3                None  0.000    0.045238    75.408867
# 3             4     34_4                None  0.001    0.060457   102.438843
# 4             5     34_5                None  0.003    0.259570   206.013992
# ...         ...      ...                 ...    ...         ...          ...
# 12212      9192  32_509a   Pollacappul Lough  0.254   25.509374  3827.503729
# 12213      9193  32_509b      Kylemore Lough  1.335  134.091553  6016.860382
# 12214      9194  26_747c         Tap (Lough)  0.112   11.254331  2149.103677
# 12215       937   32_402  Beaghcauneen Lough  0.184   18.520070  3378.220801
# 12216       938   32_403    Connor ( Lough )  0.002    0.166810   160.635907
#
# ...

# %%
lak.plot(color='red',figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
#Displaying both shape file together 
fig,ax=plt.subplots(1,figsize=(10,10)) 
riv.plot(ax=ax) 
lak.plot(ax=ax,cmap='jet',column='PERIMETER')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #Displaying both shape file together
# fig,ax=plt.subplots(1,figsize=(10,10))
# riv.plot(ax=ax)
# lak.plot(ax=ax,cmap='jet',column='PERIMETER')

# %%
#Intersection between River and Lakes
Rivers_merged_lake=gpd.overlay(riv,lak,how='intersection')
Rivers_merged_lake.plot(figsize=(10,10),cmap='jet',column='PERIMETER')
# Out:
# <AxesSubplot:>

# %%
Rivers_merged_lake['Area(km2)']=Rivers_merged_lake.area/1000

# %%
print(Rivers_merged_lake)
# Out:
#       OBJECTID_1  SEG_CD_1           EPA_NAME EPA_CODE  ORDER__1 CONTINUA  \
# 0         350350  01_100_1               None     None         1        L
# 1         350362  01_101_1               None     None         1        L
# 2         350363  01_101_2               None     None         1        L
# 3         350364  01_101_3               None     None         3        L
# 4         350365  01_101_4               None     None         3        L
# ...          ...       ...                ...      ...       ...      ...
# 8868      462314     40_40  Rock Art Lake Fad    40R14         1     None
# 8869      462426    40_5_1               None     None         1        L
# 8870      462538    40_6_1               None     None         1        L
# 8871      462617    40_671     Callybear Lake    40C78         1     None
# 8872      462648    40_7_1               None     None         1        L
#
#                RWB_CD LWB_CD TWB_CD  SegmentLen  ... HYDRO_AR  ORDER__2  \
# ...
